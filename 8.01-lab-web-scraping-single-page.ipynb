# %% [markdown]
# 1 - Scraping popular songs
#
# Your product will take a song as an input from the user and will output another song (the recommendation). In most cases, the recommended song will have to be similar to the inputted song, but the CTO thinks that if the song is on the top charts at the moment, the user will enjoy more a recommendation of a song that's also popular at the moment.
#
# You have find data on the internet about currently popular songs. Billboard maintains a weekly Top 100 of "hot" songs here: https://www.billboard.com/charts/hot-100.
#
# It's a good place to start! Scrape the current top 100 songs and their respective artists, and put the information into a pandas dataframe.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
r = requests.get('https://www.billboard.com/charts/hot-100')
r.status_code
# Out:
# 200

# %%
html = r.content
soup = BeautifulSoup(html, 'html.parser')
#print(soup.prettify())

# %%
html_song1 = soup.find_all('h3', attrs={'class':'c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet'})
html_song1
# Out:
# [<h3 class="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet" id="title-of-a-story">
#
#
#
#
#  					Flowers
#
#  </h3>]

# %%
html_song99 = soup.find_all('h3', attrs={'class':'c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only'})

# %%
html_title = html_song1 + html_song99
html_title
# Out:
# [<h3 class="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet" id="title-of-a-story">
#
#
#
#
#  					Flowers
#
#  </h3>,
#  <h3 class="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only" id="title-of-a-story">
#
#
#
#
#  					Last Night
#
#  </h3>,
#  <h3 class="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only" id="title-of-a-story">
#
#
#
#
#  					Kill Bill
#
#  </h3>,
# ...

# %%
len(html_title)
# Out:
# 100

# %%
titles = [i.get_text(strip=True) for i in html_title]
titles
# Out:
# ['Flowers',
#  'Last Night',
#  'Kill Bill',
#  'Die For You',
#  "Creepin'",
#  "Boy's A Liar, Pt. 2",
#  'Anti-Hero',
#  'Calm Down',
#  'Thought You Should Know',
#  'You Proof',
#  'Rock And A Hard Place',
#  'Players',
#  'Unholy',
#  "I'm Good (Blue)",
#  'As It Was',
#  'Under The Influence',
#  "Thinkin' Bout Me",
#  'Just Wanna Rock',
#  'TQG',
#  'One Thing At A Time',
#  'Thank God',
#  'Cuff It',
#  'Escapism',
#  'Sure Thing',
#  'Lavender Haze',
#  'Rich Flex',
#  'Going, Going, Gone',
#  'Until I Found You',
#  'Everything I Love',
#  'Something In The Orange',
#  "Ain't That Some",
#  'River',
#  'I Wrote The Book',
#  'Superhero (Heroes & Villains)',
#  'Snooze',
#  'Favorite Song',
#  'Red Ruby Da Sleeze',
#  'Heart Like A Truck',
#  'Shirt',
#  'Golden Hour',
#  'Man Made A Bar',
#  'Wait In The Truck',
#  'Bloody Mary',
#  'Bzrp Music Sessions, Vol. 53',
#  'Spin Bout U',
#  'Made You Look',
#  'Bebe Dame',
#  "'98 Braves",
#  'Sunrise',
#  'Nobody Gets Me',
# ...

# %%
html_artist1 = soup.find_all('span', attrs={'class':'c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet'})
html_artist1
# Out:
# [<span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet">
#
#  	Miley Cyrus
#  </span>]

# %%
html_artist99 = soup.find_all('span', attrs={'class':'c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only'})

# %%
html_artist = html_artist1 + html_artist99
html_artist
# Out:
# [<span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet">
#
#  	Miley Cyrus
#  </span>,
#  <span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only">
#
#  	Morgan Wallen
#  </span>,
#  <span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only">
#
#  	SZA
#  </span>,
# ...

# %%
len(html_artist)
# Out:
# 100

# %%
artists = [i.get_text(strip=True) for i in html_artist]
artists
# Out:
# ['Miley Cyrus',
#  'Morgan Wallen',
#  'SZA',
#  'The Weeknd & Ariana Grande',
#  'Metro Boomin, The Weeknd & 21 Savage',
#  'PinkPantheress & Ice Spice',
#  'Taylor Swift',
#  'Rema & Selena Gomez',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Bailey Zimmerman',
#  'Coi Leray',
#  'Sam Smith & Kim Petras',
#  'David Guetta & Bebe Rexha',
#  'Harry Styles',
#  'Chris Brown',
#  'Morgan Wallen',
#  'Lil Uzi Vert',
#  'Karol G x Shakira',
#  'Morgan Wallen',
#  'Kane Brown With Katelyn Brown',
#  'Beyonce',
#  'RAYE Featuring 070 Shake',
#  'Miguel',
#  'Taylor Swift',
#  'Drake & 21 Savage',
#  'Luke Combs',
#  'Stephen Sanchez',
#  'Morgan Wallen',
#  'Zach Bryan',
#  'Morgan Wallen',
#  'Miley Cyrus',
#  'Morgan Wallen',
#  'Metro Boomin, Future & Chris Brown',
#  'SZA',
#  'Toosii',
#  'Nicki Minaj',
#  'Lainey Wilson',
#  'SZA',
#  'JVKE',
#  'Morgan Wallen Featuring Eric Church',
#  'HARDY Featuring Lainey Wilson',
#  'Lady Gaga',
#  'Bizarrap & Shakira',
#  'Drake & 21 Savage',
# ...

# %%
top_100 = list(zip(titles,artists))

# %%
pd.DataFrame(top_100, columns = ['song_name','artist_name'])
# Out:
#                  song_name                                   artist_name
# 0                  Flowers                                   Miley Cyrus
# 1               Last Night                                 Morgan Wallen
# 2                Kill Bill                                           SZA
# 3              Die For You                    The Weeknd & Ariana Grande
# 4                 Creepin'          Metro Boomin, The Weeknd & 21 Savage
# ..                     ...                                           ...
# 95         180 (Lifestyle)                                 Morgan Wallen
# 96                 F150-50                                 Morgan Wallen
# 97         Private Landing  Don Toliver Featuring Justin Bieber & Future
# 98  Dancin' In The Country                                 Tyler Hubbard
# 99         Wine Into Water                                 Morgan Wallen
#
# [100 rows x 2 columns]
